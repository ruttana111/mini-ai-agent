# %% [markdown]
# <a href="https://colab.research.google.com/github/ruttana111/mini-ai-agent/blob/main/Lab3LogisticReg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 3: Logistic Regression Model

# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://github.com/toche7/DataSets/raw/main/apple.csv")

# %%
df.head()
# Out:
#    Weight  Size   Class
# 0      69  4.39  orange
# 1      69  4.21  orange
# 2      65  4.09  orange
# 3      72  5.85   apple
# 4      67  4.70  orange

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %% [markdown]
# ### Data Preparation

# %%
X = df[['Weight','Size']]
X.head()
# Out:
#    Weight  Size
# 0      69  4.39
# 1      69  4.21
# 2      65  4.09
# 3      72  5.85
# 4      67  4.70

# %%
y = df[['Class']]
y.head()
# Out:
#     Class
# 0  orange
# 1  orange
# 2  orange
# 3   apple
# 4  orange

# %% [markdown]
# ### Create Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgModel = LogisticRegression()

# %% [markdown]
# ### Train Model

# %%
lgModel.fit(X,y)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %% [markdown]
# ### Evaluation

# %%
lgModel.score(X,y)
# Out:
# 1.0

# %% [markdown]
# ### Prediction

# %%
lgModel.predict(X)
# Out:
# array(['orange', 'orange', 'orange', 'apple', 'orange', 'apple', 'apple',
#        'apple', 'apple', 'orange', 'apple', 'apple', 'apple', 'orange',
#        'apple', 'orange', 'orange', 'apple', 'orange', 'apple', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'apple', 'orange',
#        'orange', 'apple', 'apple', 'apple', 'apple', 'orange', 'orange',
#        'apple', 'apple'], dtype=object)

# %%
t1 = [[70,4.3]]
t1
# Out:
# [[70, 4.3]]

# %%
lgModel.predict(t1)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['orange'], dtype=object)

# %%
t = [[70,4.3],[68,5.6]]

# %%
lgModel.predict(t)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['orange', 'orange'], dtype=object)

# %% [markdown]
# ### Save Model

# %%
from joblib import dump
